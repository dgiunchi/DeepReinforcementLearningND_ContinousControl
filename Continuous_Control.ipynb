# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
env = UnityEnvironment(file_name='./Reacher_Windows_x86_64/Reacher.exe')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 1
# Size of each action: 4
# There are 1 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726671e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))
# Out:
# Total score (averaged over agents) this episode: 0.0

# %% [markdown]
# When finished, you can close the environment.

# %%
#env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
import torch
from collections import deque

import matplotlib.pyplot as plt
# %matplotlib inline

from ddpg_agent import Agent

def ddpg(n_episodes=400, max_t=500):
    avg_score = []
    solved = False
    env_info = env.reset(train_mode=True)[brain_name]

    states = env_info.vector_observations

    agent_kwargs = {"state_size": state_size, "action_size": action_size, "random_seed": 2,}
    agents = [Agent(**agent_kwargs) for _ in range(num_agents)]

    assert len(agents) == num_agents
    actions = [agent.act(states[index]) for index, agent in enumerate(agents)]
    
    chkpt_episodes = 100
    scores_deque = deque(maxlen=100)
    scores = np.zeros(num_agents)

    time_steps = 15
    num_update = 10
    len_agents = len(str(num_agents))
    
    for i_episode in range(1, n_episodes+1):
        states = env_info.vector_observations                  # get the current state (for each agent)
        for agent in agents:
            agent.reset()

        for t in range(max_t):
            actions = [agent.act(states[index]) for index, agent in enumerate(agents)]
            
            env_info = env.step(actions)[brain_name]
            next_states = env_info.vector_observations         # get next state (for each agent)
            rewards = env_info.rewards                         # get reward (for each agent)
            dones = env_info.local_done                        # see if episode finished
            
            step_tuple = zip(agents, states, actions, rewards, next_states, dones)
            
            for agent, s, a, r, s_, d in step_tuple:
                agent.memory.add(s, a, r, s_, d)
                if ( t % time_steps == 0):
                    agent.step(num_update)
            states  = next_states
            scores += rewards                                  # update the score (for each agent)
            if np.any(dones):                                  # exit loop if episode finished
                break
                
        score = np.mean(scores)        
        avg_score.append(score)
        scores_deque.append(score)

        avg = np.mean(scores_deque)
            
        print('\rEpisode {}\tAverage Score: {:.2f}\tScore: {:.2f} \tMax Score: {:.2f}'.format(i_episode, avg, score, np.max(scores_deque)), end="\n")

        if not solved and np.mean(scores_deque) > 30.:
            print("\r\renv __solved__ @ i_episode={i_episode}, w/ avg_score={avg:.2f}\r".format(i_episode=i_episode, avg=avg))
            solved = True
        
        
        if i_episode % chkpt_episodes == 0:
            print("\repisodes: {i_episode}\tavg: {avg:.2f}".format(i_episode=i_episode, avg=avg))

            for idx, agent in enumerate(agents):
                chkpt_path_actor = "actor_" + str(idx).zfill(len_agents) + ".pth"
                torch.save(agent.actor_local.state_dict(), chkpt_path_actor)

                chkpt_path_critic = "critic_" + str(idx).zfill(len_agents) + ".pth"
                torch.save(agent.critic_local.state_dict(), chkpt_path_critic)

    return avg_score

# %%
#env = UnityEnvironment(file_name='./Reacher_Windows_x86_64/Reacher.exe')
#brain_name = env.brain_names[0]
#brain = env.brains[brain_name]
#env_info = env.reset(train_mode=True)[brain_name]
scores = ddpg()
# Out:
# Episode 1	Average Score: 0.39	Score: 0.39 	Max Score: 0.39
# Episode 2	Average Score: 0.39	Score: 0.39 	Max Score: 0.39
# Episode 3	Average Score: 0.39	Score: 0.39 	Max Score: 0.39
# Episode 4	Average Score: 0.64	Score: 1.41 	Max Score: 1.41
# Episode 5	Average Score: 0.84	Score: 1.64 	Max Score: 1.64
# Episode 6	Average Score: 0.98	Score: 1.64 	Max Score: 1.64
# Episode 7	Average Score: 1.15	Score: 2.21 	Max Score: 2.21
# Episode 8	Average Score: 1.28	Score: 2.21 	Max Score: 2.21
# Episode 9	Average Score: 1.39	Score: 2.21 	Max Score: 2.21
# Episode 10	Average Score: 1.47	Score: 2.21 	Max Score: 2.21
# Episode 11	Average Score: 1.54	Score: 2.21 	Max Score: 2.21
# Episode 12	Average Score: 1.59	Score: 2.21 	Max Score: 2.21
# Episode 13	Average Score: 1.64	Score: 2.21 	Max Score: 2.21
# Episode 14	Average Score: 1.68	Score: 2.21 	Max Score: 2.21
# Episode 15	Average Score: 1.72	Score: 2.21 	Max Score: 2.21
# Episode 16	Average Score: 1.75	Score: 2.21 	Max Score: 2.21
# Episode 17	Average Score: 1.77	Score: 2.21 	Max Score: 2.21
# Episode 18	Average Score: 1.80	Score: 2.21 	Max Score: 2.21
# Episode 19	Average Score: 1.83	Score: 2.35 	Max Score: 2.35
# Episode 20	Average Score: 1.86	Score: 2.42 	Max Score: 2.42
# Episode 21	Average Score: 1.88	Score: 2.42 	Max Score: 2.42
# Episode 22	Average Score: 1.95	Score: 3.27 	Max Score: 3.27
# Episode 23	Average Score: 2.00	Score: 3.27 	Max Score: 3.27
# Episode 24	Average Score: 2.06	Score: 3.27 	Max Score: 3.27
# Episode 25	Average Score: 2.11	Score: 3.27 	Max Score: 3.27
# Episode 26	Average Score: 2.15	Score: 3.27 	Max Score: 3.27
# Episode 27	Average Score: 2.19	Score: 3.27 	Max Score: 3.27
# Episode 28	Average Score: 2.23	Score: 3.27 	Max Score: 3.27
# Episode 29	Average Score: 2.27	Score: 3.27 	Max Score: 3.27
# Episode 30	Average Score: 2.30	Score: 3.27 	Max Score: 3.27
# Episode 31	Average Score: 2.33	Score: 3.27 	Max Score: 3.27
# Episode 32	Average Score: 2.36	Score: 3.27 	Max Score: 3.27
# Episode 33	Average Score: 2.39	Score: 3.27 	Max Score: 3.27
# Episode 34	Average Score: 2.42	Score: 3.36 	Max Score: 3.36
# Episode 35	Average Score: 2.44	Score: 3.36 	Max Score: 3.36
# Episode 36	Average Score: 2.47	Score: 3.36 	Max Score: 3.36
# Episode 37	Average Score: 2.49	Score: 3.36 	Max Score: 3.36
# Episode 38	Average Score: 2.52	Score: 3.36 	Max Score: 3.36
# Episode 39	Average Score: 2.54	Score: 3.36 	Max Score: 3.36
# Episode 40	Average Score: 2.56	Score: 3.36 	Max Score: 3.36
# Episode 41	Average Score: 2.58	Score: 3.36 	Max Score: 3.36
# Episode 42	Average Score: 2.60	Score: 3.36 	Max Score: 3.36
# Episode 43	Average Score: 2.61	Score: 3.36 	Max Score: 3.36
# Episode 44	Average Score: 2.63	Score: 3.36 	Max Score: 3.36
# Episode 45	Average Score: 2.65	Score: 3.36 	Max Score: 3.36
# Episode 46	Average Score: 2.66	Score: 3.36 	Max Score: 3.36
# Episode 47	Average Score: 2.68	Score: 3.49 	Max Score: 3.49
# Episode 48	Average Score: 2.70	Score: 3.49 	Max Score: 3.49
# Episode 49	Average Score: 2.71	Score: 3.56 	Max Score: 3.56
# Episode 50	Average Score: 2.73	Score: 3.71 	Max Score: 3.71
# Episode 51	Average Score: 2.75	Score: 3.71 	Max Score: 3.71
# Episode 52	Average Score: 2.80	Score: 5.09 	Max Score: 5.09
# Episode 53	Average Score: 2.84	Score: 5.09 	Max Score: 5.09
# Episode 54	Average Score: 2.88	Score: 5.09 	Max Score: 5.09
# Episode 55	Average Score: 2.92	Score: 5.09 	Max Score: 5.09
# Episode 56	Average Score: 2.96	Score: 5.09 	Max Score: 5.09
# Episode 57	Average Score: 3.00	Score: 5.09 	Max Score: 5.09
# Episode 58	Average Score: 3.04	Score: 5.22 	Max Score: 5.22
# Episode 59	Average Score: 3.08	Score: 5.72 	Max Score: 5.72
# Episode 60	Average Score: 3.13	Score: 5.72 	Max Score: 5.72
# Episode 61	Average Score: 3.17	Score: 5.72 	Max Score: 5.72
# Episode 62	Average Score: 3.21	Score: 5.72 	Max Score: 5.72
# Episode 63	Average Score: 3.25	Score: 5.72 	Max Score: 5.72
# Episode 64	Average Score: 3.29	Score: 5.72 	Max Score: 5.72
# Episode 65	Average Score: 3.33	Score: 5.85 	Max Score: 5.85
# Episode 66	Average Score: 3.37	Score: 5.85 	Max Score: 5.85
# Episode 67	Average Score: 3.41	Score: 5.99 	Max Score: 5.99
# Episode 68	Average Score: 3.44	Score: 6.03 	Max Score: 6.03
# Episode 69	Average Score: 3.48	Score: 6.03 	Max Score: 6.03
# Episode 70	Average Score: 3.52	Score: 6.39 	Max Score: 6.39
# Episode 71	Average Score: 3.57	Score: 6.50 	Max Score: 6.50
# Episode 72	Average Score: 3.61	Score: 6.50 	Max Score: 6.50
# Episode 73	Average Score: 3.65	Score: 6.91 	Max Score: 6.91
# Episode 74	Average Score: 3.70	Score: 7.32 	Max Score: 7.32
# Episode 75	Average Score: 3.75	Score: 7.32 	Max Score: 7.32
# Episode 76	Average Score: 3.80	Score: 7.32 	Max Score: 7.32
# Episode 77	Average Score: 3.84	Score: 7.32 	Max Score: 7.32
# Episode 78	Average Score: 3.89	Score: 7.32 	Max Score: 7.32
# Episode 79	Average Score: 3.93	Score: 7.53 	Max Score: 7.53
# Episode 80	Average Score: 3.99	Score: 8.16 	Max Score: 8.16
# Episode 81	Average Score: 4.04	Score: 8.16 	Max Score: 8.16
# Episode 82	Average Score: 4.09	Score: 8.16 	Max Score: 8.16
# Episode 83	Average Score: 4.14	Score: 8.16 	Max Score: 8.16
# Episode 84	Average Score: 4.18	Score: 8.16 	Max Score: 8.16
# Episode 85	Average Score: 4.23	Score: 8.16 	Max Score: 8.16
# Episode 86	Average Score: 4.28	Score: 8.28 	Max Score: 8.28
# Episode 87	Average Score: 4.32	Score: 8.28 	Max Score: 8.28
# Episode 88	Average Score: 4.37	Score: 8.72 	Max Score: 8.72
# Episode 89	Average Score: 4.43	Score: 8.98 	Max Score: 8.98
# Episode 90	Average Score: 4.48	Score: 8.98 	Max Score: 8.98
# Episode 91	Average Score: 4.53	Score: 9.44 	Max Score: 9.44
# Episode 92	Average Score: 4.59	Score: 10.23 	Max Score: 10.23
# Episode 93	Average Score: 4.65	Score: 10.23 	Max Score: 10.23
# Episode 94	Average Score: 4.71	Score: 10.23 	Max Score: 10.23
# Episode 95	Average Score: 4.77	Score: 10.30 	Max Score: 10.30
# Episode 96	Average Score: 4.83	Score: 10.30 	Max Score: 10.30
# Episode 97	Average Score: 4.89	Score: 10.30 	Max Score: 10.30
# Episode 98	Average Score: 4.94	Score: 10.30 	Max Score: 10.30
# Episode 99	Average Score: 5.00	Score: 10.30 	Max Score: 10.30
# Episode 100	Average Score: 5.06	Score: 11.22 	Max Score: 11.22
# episodes: 100	avg: 5.06
# Episode 101	Average Score: 5.17	Score: 11.66 	Max Score: 11.66
# Episode 102	Average Score: 5.28	Score: 11.70 	Max Score: 11.70
# Episode 103	Average Score: 5.40	Score: 12.20 	Max Score: 12.20
# Episode 104	Average Score: 5.52	Score: 12.80 	Max Score: 12.80
# Episode 105	Average Score: 5.63	Score: 12.80 	Max Score: 12.80
# Episode 106	Average Score: 5.74	Score: 13.25 	Max Score: 13.25
# Episode 107	Average Score: 5.87	Score: 14.53 	Max Score: 14.53
# Episode 108	Average Score: 5.99	Score: 14.53 	Max Score: 14.53
# Episode 109	Average Score: 6.12	Score: 15.35 	Max Score: 15.35
# Episode 110	Average Score: 6.26	Score: 16.39 	Max Score: 16.39
# Episode 111	Average Score: 6.40	Score: 16.39 	Max Score: 16.39
# Episode 112	Average Score: 6.55	Score: 16.99 	Max Score: 16.99
# Episode 113	Average Score: 6.71	Score: 17.69 	Max Score: 17.69
# Episode 114	Average Score: 6.86	Score: 17.69 	Max Score: 17.69
# Episode 115	Average Score: 7.02	Score: 17.69 	Max Score: 17.69
# Episode 116	Average Score: 7.18	Score: 18.65 	Max Score: 18.65
# Episode 117	Average Score: 7.35	Score: 18.65 	Max Score: 18.65
# Episode 118	Average Score: 7.52	Score: 19.31 	Max Score: 19.31
# Episode 119	Average Score: 7.69	Score: 19.67 	Max Score: 19.67
# Episode 120	Average Score: 7.86	Score: 19.67 	Max Score: 19.67
# Episode 121	Average Score: 8.04	Score: 20.01 	Max Score: 20.01
# Episode 122	Average Score: 8.21	Score: 20.03 	Max Score: 20.03
# Episode 123	Average Score: 8.37	Score: 20.03 	Max Score: 20.03
# Episode 124	Average Score: 8.55	Score: 20.81 	Max Score: 20.81
# Episode 125	Average Score: 8.73	Score: 21.19 	Max Score: 21.19
# Episode 126	Average Score: 8.91	Score: 21.19 	Max Score: 21.19
# Episode 127	Average Score: 9.10	Score: 22.12 	Max Score: 22.12
# Episode 128	Average Score: 9.29	Score: 22.96 	Max Score: 22.96
# Episode 129	Average Score: 9.49	Score: 22.96 	Max Score: 22.96
# Episode 130	Average Score: 9.69	Score: 23.82 	Max Score: 23.82
# Episode 131	Average Score: 9.91	Score: 24.67 	Max Score: 24.67
# Episode 132	Average Score: 10.12	Score: 24.67 	Max Score: 24.67
# Episode 133	Average Score: 10.34	Score: 25.21 	Max Score: 25.21
# Episode 134	Average Score: 10.57	Score: 25.87 	Max Score: 25.87
# Episode 135	Average Score: 10.79	Score: 25.87 	Max Score: 25.87
# Episode 136	Average Score: 11.02	Score: 25.87 	Max Score: 25.87
# Episode 137	Average Score: 11.25	Score: 26.80 	Max Score: 26.80
# Episode 138	Average Score: 11.49	Score: 26.84 	Max Score: 26.84
# Episode 139	Average Score: 11.73	Score: 27.72 	Max Score: 27.72
# Episode 140	Average Score: 11.99	Score: 29.44 	Max Score: 29.44
# Episode 141	Average Score: 12.25	Score: 29.44 	Max Score: 29.44
# Episode 142	Average Score: 12.51	Score: 29.44 	Max Score: 29.44
# Episode 143	Average Score: 12.79	Score: 31.29 	Max Score: 31.29
# Episode 144	Average Score: 13.07	Score: 31.29 	Max Score: 31.29
# Episode 145	Average Score: 13.36	Score: 32.00 	Max Score: 32.00
# Episode 146	Average Score: 13.65	Score: 32.50 	Max Score: 32.50
# Episode 147	Average Score: 13.94	Score: 32.50 	Max Score: 32.50
# Episode 148	Average Score: 14.23	Score: 32.75 	Max Score: 32.75
# Episode 149	Average Score: 14.52	Score: 32.75 	Max Score: 32.75
# Episode 150	Average Score: 14.81	Score: 32.75 	Max Score: 32.75
# Episode 151	Average Score: 15.11	Score: 33.55 	Max Score: 33.55
# Episode 152	Average Score: 15.40	Score: 33.55 	Max Score: 33.55
# Episode 153	Average Score: 15.68	Score: 33.55 	Max Score: 33.55
# Episode 154	Average Score: 15.97	Score: 33.76 	Max Score: 33.76
# Episode 155	Average Score: 16.26	Score: 34.12 	Max Score: 34.12
# Episode 156	Average Score: 16.55	Score: 34.12 	Max Score: 34.12
# Episode 157	Average Score: 16.84	Score: 34.12 	Max Score: 34.12
# Episode 158	Average Score: 17.13	Score: 34.63 	Max Score: 34.63
# Episode 159	Average Score: 17.42	Score: 34.63 	Max Score: 34.63
# Episode 160	Average Score: 17.71	Score: 34.63 	Max Score: 34.63
# Episode 161	Average Score: 18.01	Score: 35.27 	Max Score: 35.27
# Episode 162	Average Score: 18.30	Score: 35.27 	Max Score: 35.27
# Episode 163	Average Score: 18.60	Score: 35.49 	Max Score: 35.49
# Episode 164	Average Score: 18.91	Score: 36.96 	Max Score: 36.96
# Episode 165	Average Score: 19.22	Score: 36.96 	Max Score: 36.96
# Episode 166	Average Score: 19.54	Score: 37.50 	Max Score: 37.50
# Episode 167	Average Score: 19.87	Score: 38.89 	Max Score: 38.89
# Episode 168	Average Score: 20.20	Score: 38.89 	Max Score: 38.89
# Episode 169	Average Score: 20.53	Score: 39.51 	Max Score: 39.51
# Episode 170	Average Score: 20.87	Score: 39.66 	Max Score: 39.66
# Episode 171	Average Score: 21.20	Score: 39.66 	Max Score: 39.66
# Episode 172	Average Score: 21.53	Score: 39.86 	Max Score: 39.86
# Episode 173	Average Score: 21.88	Score: 41.48 	Max Score: 41.48
# Episode 174	Average Score: 22.22	Score: 41.48 	Max Score: 41.48
# Episode 175	Average Score: 22.56	Score: 41.83 	Max Score: 41.83
# Episode 176	Average Score: 22.91	Score: 42.09 	Max Score: 42.09
# Episode 177	Average Score: 23.26	Score: 42.09 	Max Score: 42.09
# Episode 178	Average Score: 23.61	Score: 42.59 	Max Score: 42.59
# Episode 179	Average Score: 23.97	Score: 43.50 	Max Score: 43.50
# Episode 180	Average Score: 24.32	Score: 43.50 	Max Score: 43.50
# Episode 181	Average Score: 24.69	Score: 44.80 	Max Score: 44.80
# Episode 182	Average Score: 25.07	Score: 46.44 	Max Score: 46.44
# Episode 183	Average Score: 25.46	Score: 46.44 	Max Score: 46.44
# Episode 184	Average Score: 25.84	Score: 46.50 	Max Score: 46.50
# Episode 185	Average Score: 26.23	Score: 46.87 	Max Score: 46.87
# Episode 186	Average Score: 26.61	Score: 46.87 	Max Score: 46.87
# Episode 187	Average Score: 27.00	Score: 47.48 	Max Score: 47.48
# Episode 188	Average Score: 27.41	Score: 49.00 	Max Score: 49.00
# Episode 189	Average Score: 27.81	Score: 49.00 	Max Score: 49.00
# Episode 190	Average Score: 28.22	Score: 49.76 	Max Score: 49.76
# Episode 191	Average Score: 28.64	Score: 51.77 	Max Score: 51.77
# Episode 192	Average Score: 29.05	Score: 51.81 	Max Score: 51.81
# Episode 193	Average Score: 29.48	Score: 52.84 	Max Score: 52.84
# Episode 194	Average Score: 29.91	Score: 53.19 	Max Score: 53.19
# Episode 195	Average Score: 30.34	Score: 53.19 	Max Score: 53.19
# env __solved__ @ i_episode=195, w/ avg_score=30.34
# Episode 196	Average Score: 30.77	Score: 53.78 	Max Score: 53.78
# Episode 197	Average Score: 31.22	Score: 55.38 	Max Score: 55.38
# Episode 198	Average Score: 31.68	Score: 55.38 	Max Score: 55.38
# Episode 199	Average Score: 32.13	Score: 55.38 	Max Score: 55.38
# Episode 200	Average Score: 32.58	Score: 56.69 	Max Score: 56.69
# episodes: 200	avg: 32.58
# Episode 201	Average Score: 33.03	Score: 56.69 	Max Score: 56.69
# Episode 202	Average Score: 33.49	Score: 57.70 	Max Score: 57.70
# Episode 203	Average Score: 33.95	Score: 58.14 	Max Score: 58.14
# Episode 204	Average Score: 34.40	Score: 58.14 	Max Score: 58.14
# Episode 205	Average Score: 34.87	Score: 59.43 	Max Score: 59.43
# Episode 206	Average Score: 35.34	Score: 60.32 	Max Score: 60.32
# Episode 207	Average Score: 35.80	Score: 60.32 	Max Score: 60.32
# Episode 208	Average Score: 36.26	Score: 60.57 	Max Score: 60.57
# Episode 209	Average Score: 36.72	Score: 61.04 	Max Score: 61.04
# Episode 210	Average Score: 37.16	Score: 61.04 	Max Score: 61.04
# Episode 211	Average Score: 37.62	Score: 62.11 	Max Score: 62.11
# Episode 212	Average Score: 38.08	Score: 62.57 	Max Score: 62.57
# Episode 213	Average Score: 38.52	Score: 62.57 	Max Score: 62.57
# Episode 214	Average Score: 38.98	Score: 63.56 	Max Score: 63.56
# Episode 215	Average Score: 39.46	Score: 65.00 	Max Score: 65.00
# Episode 216	Average Score: 39.92	Score: 65.00 	Max Score: 65.00
# Episode 217	Average Score: 40.39	Score: 65.99 	Max Score: 65.99
# Episode 218	Average Score: 40.87	Score: 66.57 	Max Score: 66.57
# Episode 219	Average Score: 41.33	Score: 66.57 	Max Score: 66.57
# Episode 220	Average Score: 41.81	Score: 67.46 	Max Score: 67.46
# Episode 221	Average Score: 42.30	Score: 68.69 	Max Score: 68.69
# Episode 222	Average Score: 42.79	Score: 68.69 	Max Score: 68.69
# Episode 223	Average Score: 43.29	Score: 70.08 	Max Score: 70.08
# Episode 224	Average Score: 43.78	Score: 70.50 	Max Score: 70.50
# Episode 225	Average Score: 44.28	Score: 70.50 	Max Score: 70.50
# Episode 226	Average Score: 44.81	Score: 74.82 	Max Score: 74.82
# Episode 227	Average Score: 45.35	Score: 75.35 	Max Score: 75.35
# Episode 228	Average Score: 45.87	Score: 75.35 	Max Score: 75.35
# Episode 229	Average Score: 46.41	Score: 77.09 	Max Score: 77.09
# Episode 230	Average Score: 46.95	Score: 77.89 	Max Score: 77.89
# Episode 231	Average Score: 47.48	Score: 77.89 	Max Score: 77.89
# Episode 232	Average Score: 48.03	Score: 79.26 	Max Score: 79.26
# Episode 233	Average Score: 48.58	Score: 80.18 	Max Score: 80.18
# Episode 234	Average Score: 49.12	Score: 80.18 	Max Score: 80.18
# Episode 235	Average Score: 49.67	Score: 80.92 	Max Score: 80.92
# Episode 236	Average Score: 50.23	Score: 81.23 	Max Score: 81.23
# Episode 237	Average Score: 50.77	Score: 81.23 	Max Score: 81.23
# Episode 238	Average Score: 51.32	Score: 81.41 	Max Score: 81.41
# Episode 239	Average Score: 51.87	Score: 83.33 	Max Score: 83.33
# Episode 240	Average Score: 52.41	Score: 83.37 	Max Score: 83.37
# Episode 241	Average Score: 52.95	Score: 83.52 	Max Score: 83.52
# Episode 242	Average Score: 53.51	Score: 84.88 	Max Score: 84.88
# Episode 243	Average Score: 54.04	Score: 84.88 	Max Score: 84.88
# Episode 244	Average Score: 54.58	Score: 85.45 	Max Score: 85.45
# Episode 245	Average Score: 55.13	Score: 86.27 	Max Score: 86.27
# Episode 246	Average Score: 55.66	Score: 86.27 	Max Score: 86.27
# Episode 247	Average Score: 56.21	Score: 87.44 	Max Score: 87.44
# Episode 248	Average Score: 56.76	Score: 87.46 	Max Score: 87.46
# Episode 249	Average Score: 57.31	Score: 87.46 	Max Score: 87.46
# Episode 250	Average Score: 57.86	Score: 87.63 	Max Score: 87.63
# Episode 251	Average Score: 58.40	Score: 88.29 	Max Score: 88.29
# Episode 252	Average Score: 58.95	Score: 88.29 	Max Score: 88.29
# Episode 253	Average Score: 59.50	Score: 88.65 	Max Score: 88.65
# Episode 254	Average Score: 60.06	Score: 89.60 	Max Score: 89.60
# Episode 255	Average Score: 60.62	Score: 89.60 	Max Score: 89.60
# Episode 256	Average Score: 61.18	Score: 90.47 	Max Score: 90.47
# Episode 257	Average Score: 61.75	Score: 91.09 	Max Score: 91.09
# Episode 258	Average Score: 62.31	Score: 91.10 	Max Score: 91.10
# Episode 259	Average Score: 62.88	Score: 91.33 	Max Score: 91.33
# Episode 260	Average Score: 63.45	Score: 91.76 	Max Score: 91.76
# Episode 261	Average Score: 64.02	Score: 91.76 	Max Score: 91.76
# Episode 262	Average Score: 64.58	Score: 91.96 	Max Score: 91.96
# Episode 263	Average Score: 65.15	Score: 92.30 	Max Score: 92.30
# Episode 264	Average Score: 65.71	Score: 92.30 	Max Score: 92.30
# Episode 265	Average Score: 66.26	Score: 92.38 	Max Score: 92.38
# Episode 266	Average Score: 66.81	Score: 92.67 	Max Score: 92.67
# Episode 267	Average Score: 67.35	Score: 92.67 	Max Score: 92.67
# Episode 268	Average Score: 67.89	Score: 93.45 	Max Score: 93.45
# Episode 269	Average Score: 68.44	Score: 94.24 	Max Score: 94.24
# Episode 270	Average Score: 68.99	Score: 94.24 	Max Score: 94.24
# Episode 271	Average Score: 69.54	Score: 94.89 	Max Score: 94.89
# Episode 272	Average Score: 70.09	Score: 94.97 	Max Score: 94.97
# Episode 273	Average Score: 70.63	Score: 94.97 	Max Score: 94.97
# Episode 274	Average Score: 71.16	Score: 95.16 	Max Score: 95.16
# Episode 275	Average Score: 71.70	Score: 95.72 	Max Score: 95.72
# Episode 276	Average Score: 72.24	Score: 95.72 	Max Score: 95.72
# Episode 277	Average Score: 72.78	Score: 96.44 	Max Score: 96.44
# Episode 278	Average Score: 73.32	Score: 96.60 	Max Score: 96.60
# Episode 279	Average Score: 73.85	Score: 96.60 	Max Score: 96.60
# Episode 280	Average Score: 74.39	Score: 97.02 	Max Score: 97.02
# Episode 281	Average Score: 74.91	Score: 97.02 	Max Score: 97.02
# Episode 282	Average Score: 75.42	Score: 97.02 	Max Score: 97.02
# Episode 283	Average Score: 75.93	Score: 97.91 	Max Score: 97.91
# Episode 284	Average Score: 76.45	Score: 98.71 	Max Score: 98.71
# Episode 285	Average Score: 76.97	Score: 98.71 	Max Score: 98.71
# Episode 286	Average Score: 77.50	Score: 99.54 	Max Score: 99.54
# Episode 287	Average Score: 78.02	Score: 99.54 	Max Score: 99.54
# Episode 288	Average Score: 78.52	Score: 99.54 	Max Score: 99.54
# Episode 289	Average Score: 79.03	Score: 99.69 	Max Score: 99.69
# Episode 290	Average Score: 79.54	Score: 100.31 	Max Score: 100.31
# Episode 291	Average Score: 80.02	Score: 100.31 	Max Score: 100.31
# Episode 292	Average Score: 80.51	Score: 100.79 	Max Score: 100.79
# Episode 293	Average Score: 80.99	Score: 101.11 	Max Score: 101.11
# Episode 294	Average Score: 81.47	Score: 101.11 	Max Score: 101.11
# Episode 295	Average Score: 81.95	Score: 101.33 	Max Score: 101.33
# Episode 296	Average Score: 82.44	Score: 102.12 	Max Score: 102.12
# Episode 297	Average Score: 82.91	Score: 102.12 	Max Score: 102.12
# Episode 298	Average Score: 83.38	Score: 102.45 	Max Score: 102.45
# Episode 299	Average Score: 83.86	Score: 103.32 	Max Score: 103.32
# Episode 300	Average Score: 84.32	Score: 103.32 	Max Score: 103.32
# episodes: 300	avg: 84.32
# Episode 301	Average Score: 84.79	Score: 103.32 	Max Score: 103.32
# Episode 302	Average Score: 85.25	Score: 103.49 	Max Score: 103.49
# Episode 303	Average Score: 85.70	Score: 103.49 	Max Score: 103.49
# Episode 304	Average Score: 86.16	Score: 104.28 	Max Score: 104.28
# Episode 305	Average Score: 86.61	Score: 104.42 	Max Score: 104.42
# Episode 306	Average Score: 87.05	Score: 104.42 	Max Score: 104.42
# Episode 307	Average Score: 87.49	Score: 104.42 	Max Score: 104.42
# Episode 308	Average Score: 87.93	Score: 104.42 	Max Score: 104.42
# Episode 309	Average Score: 88.37	Score: 104.42 	Max Score: 104.42
# Episode 310	Average Score: 88.80	Score: 104.42 	Max Score: 104.42
# Episode 311	Average Score: 89.22	Score: 104.42 	Max Score: 104.42
# Episode 312	Average Score: 89.64	Score: 104.42 	Max Score: 104.42
# Episode 313	Average Score: 90.06	Score: 104.42 	Max Score: 104.42
# Episode 314	Average Score: 90.47	Score: 104.42 	Max Score: 104.42
# Episode 315	Average Score: 90.86	Score: 104.42 	Max Score: 104.42
# Episode 316	Average Score: 91.26	Score: 104.61 	Max Score: 104.61
# Episode 317	Average Score: 91.64	Score: 104.61 	Max Score: 104.61
# Episode 318	Average Score: 92.02	Score: 104.61 	Max Score: 104.61
# Episode 319	Average Score: 92.41	Score: 105.04 	Max Score: 105.04
# Episode 320	Average Score: 92.79	Score: 105.04 	Max Score: 105.04
# Episode 321	Average Score: 93.15	Score: 105.04 	Max Score: 105.04
# Episode 322	Average Score: 93.51	Score: 105.10 	Max Score: 105.10
# Episode 323	Average Score: 93.86	Score: 105.10 	Max Score: 105.10
# Episode 324	Average Score: 94.21	Score: 105.10 	Max Score: 105.10
# Episode 325	Average Score: 94.56	Score: 105.10 	Max Score: 105.10
# Episode 326	Average Score: 94.86	Score: 105.10 	Max Score: 105.10
# Episode 327	Average Score: 95.16	Score: 105.10 	Max Score: 105.10
# Episode 328	Average Score: 95.45	Score: 105.10 	Max Score: 105.10
# Episode 329	Average Score: 95.73	Score: 105.10 	Max Score: 105.10
# Episode 330	Average Score: 96.01	Score: 105.10 	Max Score: 105.10
# Episode 331	Average Score: 96.28	Score: 105.10 	Max Score: 105.10
# Episode 332	Average Score: 96.54	Score: 105.10 	Max Score: 105.10
# Episode 333	Average Score: 96.78	Score: 105.10 	Max Score: 105.10
# Episode 334	Average Score: 97.04	Score: 105.34 	Max Score: 105.34
# Episode 335	Average Score: 97.28	Score: 105.34 	Max Score: 105.34
# Episode 336	Average Score: 97.52	Score: 105.34 	Max Score: 105.34
# Episode 337	Average Score: 97.76	Score: 105.34 	Max Score: 105.34
# Episode 338	Average Score: 98.00	Score: 105.34 	Max Score: 105.34
# Episode 339	Average Score: 98.22	Score: 105.34 	Max Score: 105.34
# Episode 340	Average Score: 98.44	Score: 105.34 	Max Score: 105.34
# Episode 341	Average Score: 98.66	Score: 105.34 	Max Score: 105.34
# Episode 342	Average Score: 98.86	Score: 105.34 	Max Score: 105.34
# Episode 343	Average Score: 99.07	Score: 105.41 	Max Score: 105.41
# Episode 344	Average Score: 99.27	Score: 105.53 	Max Score: 105.53
# Episode 345	Average Score: 99.46	Score: 105.53 	Max Score: 105.53
# Episode 346	Average Score: 99.66	Score: 105.69 	Max Score: 105.69
# Episode 347	Average Score: 99.84	Score: 105.69 	Max Score: 105.69
# Episode 348	Average Score: 100.02	Score: 105.69 	Max Score: 105.69
# Episode 349	Average Score: 100.21	Score: 105.80 	Max Score: 105.80
# Episode 350	Average Score: 100.39	Score: 105.80 	Max Score: 105.80
# Episode 351	Average Score: 100.56	Score: 105.80 	Max Score: 105.80
# Episode 352	Average Score: 100.74	Score: 105.80 	Max Score: 105.80
# Episode 353	Average Score: 100.91	Score: 105.80 	Max Score: 105.80
# Episode 354	Average Score: 101.07	Score: 105.80 	Max Score: 105.80
# Episode 355	Average Score: 101.23	Score: 105.88 	Max Score: 105.88
# Episode 356	Average Score: 101.39	Score: 105.88 	Max Score: 105.88
# Episode 357	Average Score: 101.54	Score: 105.88 	Max Score: 105.88
# Episode 358	Average Score: 101.68	Score: 105.88 	Max Score: 105.88
# Episode 359	Average Score: 101.83	Score: 105.88 	Max Score: 105.88
# Episode 360	Average Score: 101.97	Score: 105.88 	Max Score: 105.88
# Episode 361	Average Score: 102.11	Score: 106.12 	Max Score: 106.12
# Episode 362	Average Score: 102.26	Score: 106.35 	Max Score: 106.35
# Episode 363	Average Score: 102.40	Score: 106.35 	Max Score: 106.35
# Episode 364	Average Score: 102.54	Score: 106.48 	Max Score: 106.48
# Episode 365	Average Score: 102.69	Score: 106.96 	Max Score: 106.96
# Episode 366	Average Score: 102.83	Score: 106.96 	Max Score: 106.96
# Episode 367	Average Score: 102.97	Score: 107.06 	Max Score: 107.06
# Episode 368	Average Score: 103.11	Score: 107.20 	Max Score: 107.20
# Episode 369	Average Score: 103.24	Score: 107.20 	Max Score: 107.20
# Episode 370	Average Score: 103.37	Score: 107.39 	Max Score: 107.39
# Episode 371	Average Score: 103.50	Score: 107.39 	Max Score: 107.39
# Episode 372	Average Score: 103.62	Score: 107.39 	Max Score: 107.39
# Episode 373	Average Score: 103.76	Score: 108.65 	Max Score: 108.65
# Episode 374	Average Score: 103.89	Score: 108.65 	Max Score: 108.65
# Episode 375	Average Score: 104.02	Score: 108.65 	Max Score: 108.65
# Episode 376	Average Score: 104.15	Score: 108.65 	Max Score: 108.65
# Episode 377	Average Score: 104.27	Score: 108.65 	Max Score: 108.65
# Episode 378	Average Score: 104.39	Score: 108.65 	Max Score: 108.65
# Episode 379	Average Score: 104.52	Score: 109.06 	Max Score: 109.06
# Episode 380	Average Score: 104.64	Score: 109.06 	Max Score: 109.06
# Episode 381	Average Score: 104.76	Score: 109.06 	Max Score: 109.06
# Episode 382	Average Score: 104.88	Score: 109.22 	Max Score: 109.22
# Episode 383	Average Score: 104.99	Score: 109.22 	Max Score: 109.22
# Episode 384	Average Score: 105.10	Score: 109.22 	Max Score: 109.22
# Episode 385	Average Score: 105.20	Score: 109.22 	Max Score: 109.22
# Episode 386	Average Score: 105.30	Score: 109.22 	Max Score: 109.22
# Episode 387	Average Score: 105.40	Score: 109.22 	Max Score: 109.22
# Episode 388	Average Score: 105.49	Score: 109.22 	Max Score: 109.22
# Episode 389	Average Score: 105.59	Score: 109.45 	Max Score: 109.45
# Episode 390	Average Score: 105.68	Score: 109.45 	Max Score: 109.45
# Episode 391	Average Score: 105.78	Score: 109.45 	Max Score: 109.45
# Episode 392	Average Score: 105.86	Score: 109.63 	Max Score: 109.63
# Episode 393	Average Score: 105.95	Score: 109.63 	Max Score: 109.63
# Episode 394	Average Score: 106.03	Score: 109.63 	Max Score: 109.63
# Episode 395	Average Score: 106.12	Score: 109.63 	Max Score: 109.63
# Episode 396	Average Score: 106.19	Score: 109.63 	Max Score: 109.63
# Episode 397	Average Score: 106.27	Score: 109.87 	Max Score: 109.87
# Episode 398	Average Score: 106.34	Score: 109.92 	Max Score: 109.92
# Episode 399	Average Score: 106.41	Score: 109.92 	Max Score: 109.92
# Episode 400	Average Score: 106.48	Score: 109.92 	Max Score: 109.92
# episodes: 400	avg: 106.48

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()

# %%
env.close()
